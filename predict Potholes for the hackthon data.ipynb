# %% [markdown]
# # Make prediction on the proposed challenge dataset (Scene1, Scen2, also Both videos)

# %% [markdown]
# This notebook make prediction on the Scene1, Scene2 and Both videos. You can run this notebook to get the results your self or just consult
#
# 1 - folder 'anas' for result of Scene1 including labels
#
# 2 - folder 'anas1' for result of Scene2 including labels
#
# 3 - folder 'video1' for result of video1
#
# 3 - folder 'video2' for result of video2
#
# <h2>Note<h2\>: this notebook suppose that you already cloned and yolov7 (Please run the first notebook trainning..). In case if you did not install it, install it by the executing the cell bellow and add 'best.pt' weight inside the folder 'yolov7'

# %%
# Do not run this if you already trained the model. there is no matter. go to next cell.
# Download YOLOv7 repository and install requirements
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -r requirements.txt

# %%
# %cd yolov7
# Out:
# /home/anas/Desktop/HACTHON/yolov7

# %%
# !python3 detect.py --weights 'best.pt' --conf 0.1 --source Challenge/png/Scene2 --save-txt --project 'anas1' --exist
# Out:
# Namespace(weights=['best.pt'], source='Challenge/png/Scene2', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='anas1', name='exp', exist_ok=True, no_trace=False)
# YOLOR 🚀 v0.1-116-g8c0bf3f torch 1.13.1+cu117 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/anas/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# !python3 detect.py --weights 'best.pt' --conf 0.1 --source Challenge/png/Scene1 --save-txt --project 'anas' --exist
# Out:
# Namespace(weights=['best.pt'], source='Challenge/png/Scene1', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='anas', name='exp', exist_ok=True, no_trace=False)
# YOLOR 🚀 v0.1-116-g8c0bf3f torch 1.13.1+cu117 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/anas/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...

# %%
# !python3 detect.py --weights 'best.pt' --conf 0.1 --source Challenge/png/Scene2/input.mp4 --save-txt --project 'video1' --exist
# !python3 detect.py --weights 'best.pt' --conf 0.1 --source Challenge/sections.mov --save-txt --project 'video2' --exist
# Out:
# Namespace(weights=['best.pt'], source='Challenge/png/Scene2/input.mp4', img_size=640, conf_thres=0.1, iou_thres=0.45, device='', view_img=False, save_txt=True, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='video1', name='exp', exist_ok=True, no_trace=False)
# YOLOR 🚀 v0.1-116-g8c0bf3f torch 1.13.1+cu117 CPU
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# /home/anas/.local/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...
